# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt           
# %matplotlib inline     
sns.set(color_codes=True)

# %%
df=pd.read_csv("data.csv", encoding="cp1252")
df.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
df.tail(5)
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                   Market Category Vehicle Size  Vehicle Style  highway MPG  \
# 11909  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# 11910  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# 11911  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# 11912  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# 11913                      Luxury      Midsize          Sedan           26
#
#        city mpg  Popularity   MSRP
# 11909        16         204  46120
# 11910        16         204  56670
# 11911        16         204  50620
# 11912        16         204  50920
# 11913        17          61  28995

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df=df.drop(["Popularity","Number of Doors","Driven_Wheels","Vehicle Style","Market Category","Engine Fuel Type"],axis=1)

# %%
df.head(5)
# Out:
#   Make       Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0  BMW  1 Series M  2011      335.0               6.0            MANUAL
# 1  BMW    1 Series  2011      300.0               6.0            MANUAL
# 2  BMW    1 Series  2011      300.0               6.0            MANUAL
# 3  BMW    1 Series  2011      230.0               6.0            MANUAL
# 4  BMW    1 Series  2011      230.0               6.0            MANUAL
#
#   Vehicle Size  highway MPG  city mpg   MSRP
# 0      Compact           26        19  46135
# 1      Compact           28        19  40650
# 2      Compact           28        20  36350
# 3      Compact           28        18  29450
# 4      Compact           28        18  34500

# %%
df = df.rename(columns={"Engine HP": "HP", "Engine Cylinders": "Cylinders", "Transmission Type": "Transmission", "Driven_Wheels": "Drive Mode","highway MPG": "MPG-H", "city mpg": "MPG-C", "MSRP": "Price" })
df.head(5)
# Out:
#   Make       Model  Year     HP  Cylinders Transmission Vehicle Size  MPG-H  \
# 0  BMW  1 Series M  2011  335.0        6.0       MANUAL      Compact     26
# 1  BMW    1 Series  2011  300.0        6.0       MANUAL      Compact     28
# 2  BMW    1 Series  2011  300.0        6.0       MANUAL      Compact     28
# 3  BMW    1 Series  2011  230.0        6.0       MANUAL      Compact     28
# 4  BMW    1 Series  2011  230.0        6.0       MANUAL      Compact     28
#
#    MPG-C  Price
# 0     19  46135
# 1     19  40650
# 2     20  36350
# 3     18  29450
# 4     18  34500

# %%
df.shape
# Out:
# (11914, 10)

# %%
duplicate_row_df=df[df.duplicated()]
print("Num of Duplicate row: ",duplicate_row_df.shape)
# Out:
# Num of Duplicate row:  (993, 10)

# %%
df.count()
# Out:
# Make            11914
# Model           11914
# Year            11914
# HP              11845
# Cylinders       11884
# Transmission    11914
# Vehicle Size    11914
# MPG-H           11914
# MPG-C           11914
# Price           11914
# dtype: int64

# %%
df=df.drop_duplicates()
df.head(5)
# Out:
#   Make       Model  Year     HP  Cylinders Transmission Vehicle Size  MPG-H  \
# 0  BMW  1 Series M  2011  335.0        6.0       MANUAL      Compact     26
# 1  BMW    1 Series  2011  300.0        6.0       MANUAL      Compact     28
# 2  BMW    1 Series  2011  300.0        6.0       MANUAL      Compact     28
# 3  BMW    1 Series  2011  230.0        6.0       MANUAL      Compact     28
# 4  BMW    1 Series  2011  230.0        6.0       MANUAL      Compact     28
#
#    MPG-C  Price
# 0     19  46135
# 1     19  40650
# 2     20  36350
# 3     18  29450
# 4     18  34500

# %%
df.count()
# Out:
# Make            10921
# Model           10921
# Year            10921
# HP              10852
# Cylinders       10891
# Transmission    10921
# Vehicle Size    10921
# MPG-H           10921
# MPG-C           10921
# Price           10921
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Make             0
# Model            0
# Year             0
# HP              69
# Cylinders       30
# Transmission     0
# Vehicle Size     0
# MPG-H            0
# MPG-C            0
# Price            0
# dtype: int64

# %%
df=df.dropna()
df.count()
# Out:
# Make            10823
# Model           10823
# Year            10823
# HP              10823
# Cylinders       10823
# Transmission    10823
# Vehicle Size    10823
# MPG-H           10823
# MPG-C           10823
# Price           10823
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Make            0
# Model           0
# Year            0
# HP              0
# Cylinders       0
# Transmission    0
# Vehicle Size    0
# MPG-H           0
# MPG-C           0
# Price           0
# dtype: int64

# %%
sns.boxplot(x=df["Price"])
# Out:
# <Axes: xlabel='Price'>

# %%
sns.boxplot(x=df["HP"])
# Out:
# <Axes: xlabel='HP'>

# %%
sns.boxplot(x=df["Cylinders"])
# Out:
# <Axes: xlabel='Cylinders'>

# %%
sns.boxplot(x=df["Year"])
# Out:
# <Axes: xlabel='Year'>

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Year             9.0
# HP             130.0
# Cylinders        2.0
# MPG-H            8.0
# MPG-C            6.0
# Price        21342.5
# dtype: float64
# C:\Users\Nikhil\AppData\Local\Temp\ipykernel_21788\4249959737.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1 = df.quantile(0.25)
# C:\Users\Nikhil\AppData\Local\Temp\ipykernel_21788\4249959737.py:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q3 = df.quantile(0.75)

# %%
df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df.shape
# Out:
# C:\Users\Nikhil\AppData\Local\Temp\ipykernel_21788\4147643536.py:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
# (9187, 10)

# %%
sns.boxplot(x=df["Price"])
# Out:
# <Axes: xlabel='Price'>

# %%
sns.boxplot(x=df["HP"])
# Out:
# <Axes: xlabel='HP'>

# %%
sns.boxplot(x=df["Cylinders"])
# Out:
# <Axes: xlabel='Cylinders'>

# %%
df.Make.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Number of cars by make")
plt.ylabel('Number of cars')
plt.xlabel('Make')
# Out:
# Text(0.5, 0, 'Make')

# %%
plt.figure(figsize=(10,5))
c= df.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
# C:\Users\Nikhil\AppData\Local\Temp\ipykernel_21788\2770685803.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c= df.corr()
#                Year        HP  Cylinders     MPG-H     MPG-C     Price
# Year       1.000000  0.326046  -0.136782  0.380389  0.341217  0.593424
# HP         0.326046  1.000000   0.714201 -0.443130 -0.543045  0.738926
# Cylinders -0.136782  0.714201   1.000000 -0.704252 -0.755545  0.351829
# MPG-H      0.380389 -0.443130  -0.704252  1.000000  0.939378 -0.104163
# MPG-C      0.341217 -0.543045  -0.755545  0.939378  1.000000 -0.177431
# Price      0.593424  0.738926   0.351829 -0.104163 -0.177431  1.000000

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['HP'], df['Price'])
ax.set_xlabel('HP')
ax.set_ylabel('Price')
plt.show()
